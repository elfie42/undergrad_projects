# %% [markdown]
# # Studying Mineral Formulae Module
# Written by Phoebe Martin, FA23

# %%
# import modules
import random as r
import pandas as pd

# create dataset
groups = []
sets = []
allMinerals = []
data = []

    # this data comes from the manually created dataset in the Mineral Identification Module
group1 = [{"name" : "olivine",   "formula" : "Mg_2SiO_4",                                         "streak" : "white",     "hardness" : "6.5-7","scratches" : "nail", "scratchedBy" : "none",      "luster" : "glassy",     "color" : "lightGreen",   "density" : "moderate","magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "augite",    "formula" : "(Na,Ca)(Fe,Al,Ti,Mg)(Si,Al)_2O_6",                  "streak" : "greenGray", "hardness" : "5-6.5","scratches" : "glass","scratchedBy" : "nail",      "luster" : "resinous",   "color" : "speckledGray", "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "diopside",  "formula" : "CaMgSi_2O_6",                                       "streak" : "whiteGreen","hardness" : "6",    "scratches" : "glass","scratchedBy" : "nail",      "luster" : "glassy",     "color" : "darkGreen",    "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "hornblende","formula" : "(Ca,Na)_(2-3)(Mg,Fe,Al)_5Si_6(Si,Al)_2O_(22)(OH)_2","streak" : "white",     "hardness" : "5-6",  "scratches" : "glass","scratchedBy" : "glass",     "luster" : "submetallic","color" : "black",        "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "biotite",   "formula" : "K(Mg,Fe)_3AlSi_3O_10(OH)_2",                        "streak" : "gray",      "hardness" : "2.5-3","scratches" : "none", "scratchedBy" : "fingernail","luster" : "pearly",     "color" : "blackBrown",   "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "ilmenite",  "formula" : "FeTiO_3",                                           "streak" : "brownBlack","hardness" : "5-5.5","scratches" : "penny","scratchedBy" : "glass",     "luster" : "subMetallic","color" : "black",        "density" : "high",    "magnetism" : "none", "system" : "hexagonal", "effervescence" : "none"},
          {"name" : "magnetite", "formula" : "Fe_3O_4",                                           "streak" : "black",     "hardness" : "5.5-6","scratches" : "glass","scratchedBy" : "nail",      "luster" : "metallic",   "color" : "black",        "density" : "veryHigh","magnetism" : "strong", "system" : "isometric", "effervescence" : "none"},
          {"name" : "chromite",  "formula" : "FeCr_2O_4",                                         "streak" : "brown",     "hardness" : "5.5",  "scratches" : "glass","scratchedBy" : "glass",     "luster" : "metallic",   "color" : "black",        "density" : "high",    "magnetism" : "weak", "system" : "isometric", "effervescence" : "none"}]
groups.append(group1)
sets.append("group1")
#####################################################################################################
group2 = [{"name" : "quartz",     "formula" : "SiO_2",                  "streak" : "white",   "hardness" : "7",    "scratches" : "nail", "scratchedBy" : "none",      "luster" : "glassy",    "color" : "light",       "density" : "low",     "magnetism" : "none", "system" : "hexagonal",  "effervescence" : "none"},
          {"name" : "anorthite",  "formula" : "CaAl_2Si_2O_8",          "streak" : "white",   "hardness" : "6",    "scratches" : "glass","scratchedBy" : "nail",      "luster" : "glassy",    "color" : "greyWhite",   "density" : "low",     "magnetism" : "none", "system" : "triclinic",  "effervescence" : "none"},
          {"name" : "plagioclase","formula" : "(Ca,Na)(Al,Si)_3O_8",    "streak" : "white",   "hardness" : "6-6.5","scratches" : "glass","scratchedBy" : "nail",      "luster" : "glassy",    "color" : "white",       "density" : "low",     "magnetism" : "none", "system" : "triclinic",  "effervescence" : "none"},
          {"name" : "albite",     "formula" : "NaAlSi_3O_8",            "streak" : "white",   "hardness" : "7",    "scratches" : "nail", "scratchedBy" : "none",      "luster" : "glassy",    "color" : "white",       "density" : "low",     "magnetism" : "none", "system" : "triclinic",  "effervescence" : "none"},
          {"name" : "orthoclase", "formula" : "KAlSi_3O_8",             "streak" : "white",   "hardness" : "6",    "scratches" : "glass","scratchedBy" : "nail",      "luster" : "glassy",    "color" : "pink",        "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "microcline", "formula" : "KAlSi_3O_8",             "streak" : "white",   "hardness" : "6",    "scratches" : "glass","scratchedBy" : "nail",      "luster" : "glassy",    "color" : "aqua",        "density" : "moderate","magnetism" : "none", "system" : "triclinic",  "effervescence" : "none"},
          {"name" : "sanidine",   "formula" : "(K,Na)(Si,Al)_4O_8",     "streak" : "white",   "hardness" : "6",    "scratches" : "glass","scratchedBy" : "nail",      "luster" : "pearly",    "color" : "concreteGray","density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "muscovite",  "formula" : "KAl_2(AlSi_3O_10)(OH)_2","streak" : "white",   "hardness" : "2-2.5","scratches" : "none", "scratchedBy" : "fingernail","luster" : "glassy",    "color" : "light",       "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"},
          {"name" : "zircon",     "formula" : "ZrSiO_4",                "streak" : "white",   "hardness" : "7.5",  "scratches" : "all",  "scratchedBy" : "none",      "luster" : "adamantine","color" : "red",         "density" : "high",    "magnetism" : "none", "system" : "tetragonal", "effervescence" : "none"},
          {"name" : "apatite",    "formula" : "n/a",                    "streak" : "white",   "hardness" : "5",    "scratches" : "penny","scratchedBy" : "glass",     "luster" : "glassy",    "color" : "turquoise",   "density" : "moderate","magnetism" : "none", "system" : "hexagonal",  "effervescence" : "none"},
          {"name" : "sphene",     "formula" : "n/a",                    "streak" : "redWhite","hardness" : "5-5.5","scratches" : "glass","scratchedBy" : "glass",     "luster" : "resinous",  "color" : "green",       "density" : "moderate","magnetism" : "none", "system" : "monoclinic", "effervescence" : "none"}]
groups.append(group2)
sets.append("group2")
#####################################################################################################
group3 = [{"name" : "gypsum",   "formula" : "n/a",         "streak" : "white","hardness" : "2",    "scratches" : "none",      "scratchedBy" : "fingernail","luster" : "pearly",   "color" : "white",    "density" : "low",     "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "halite",   "formula" : "n/a",         "streak" : "white","hardness" : "2.5",  "scratches" : "none",      "scratchedBy" : "fingernail","luster" : "glassy",   "color" : "white",    "density" : "low",     "magnetism" : "none", "system" : "isometric",    "effervescence" : "none"},
          {"name" : "barite",   "formula" : "n/a",         "streak" : "white","hardness" : "3-3.5","scratches" : "fingernail","scratchedBy" : "penny",     "luster" : "glassy",   "color" : "honey",    "density" : "high",    "magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "anhydrite","formula" : "n/a",         "streak" : "white","hardness" : "3.5",  "scratches" : "penny",     "scratchedBy" : "penny",     "luster" : "pearly",   "color" : "bluish",   "density" : "moderate","magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "calcite",  "formula" : "CaCO_3",      "streak" : "white","hardness" : "3",    "scratches" : "fingernail","scratchedBy" : "penny",     "luster" : "glassy",   "color" : "white",    "density" : "moderate","magnetism" : "none", "system" : "hexagonal",    "effervescence" : "none"},
          {"name" : "aragonite","formula" : "n/a",         "streak" : "white","hardness" : "3.5-4","scratches" : "penny",     "scratchedBy" : "glass",     "luster" : "glassy",   "color" : "pink",     "density" : "moderate","magnetism" : "none", "system" : "orthorhombic", "effervescence" : "yes"},
          {"name" : "dolomite", "formula" : "CaMg(CO_3)_2","streak" : "white","hardness" : "3.5-4","scratches" : "penny",     "scratchedBy" : "glass",     "luster" : "pearly",   "color" : "lightPink","density" : "moderate","magnetism" : "none", "system" : "hexagonal",    "effervescence" : "none"},
          {"name" : "sylvite",  "formula" : "n/a",         "streak" : "white","hardness" : "2.5",  "scratches" : "fingernail","scratchedBy" : "fingernail","luster" : "greasy",   "color" : "orange",   "density" : "low",     "magnetism" : "none", "system" : "isometric",    "effervescence" : "none"},
          {"name" : "magnesite","formula" : "n/a",         "streak" : "white","hardness" : "4",    "scratches" : "penny",     "scratchedBy" : "glass",     "luster" : "waxy",     "color" : "white",    "density" : "moderate","magnetism" : "none", "system" : "hexagonal",    "effervescence" : "yes"},
          {"name" : "ulexite",  "formula" : "n/a",         "streak" : "white","hardness" : "2.5",  "scratches" : "fingernail","scratchedBy" : "fingernail","luster" : "chatoyant","color" : "colorless","density" : "low",     "magnetism" : "none", "system" : "triclinic",    "effervescence" : "none"}]              
groups.append(group3)
sets.append("group3")
#####################################################################################################
group4 = [{"name" : "fluorite",     "formula" : "CaF_2",   "streak" : "white",      "hardness" : "4",     "scratches" : "penny",      "scratchedBy" : "glass",      "luster" : "glassy",   "color" : "variousBright",   "density" : "moderate", "magnetism" : "none", "system" : "cubic",        "effervescence" : "none"},
          {"name" : "chalcedony",   "formula" : "n/a",     "streak" : "white",      "hardness" : "6.5-7", "scratches" : "glass",      "scratchedBy" : "nail",       "luster" : "waxy",     "color" : "whiteBlackBrown", "density" : "moderate", "magnetism" : "none", "system" : "hexagonal",    "effervescence" : "none"},
          {"name" : "chabazite",    "formula" : "n/a",     "streak" : "white",      "hardness" : "4",     "scratches" : "penny",      "scratchedBy" : "glass",      "luster" : "glassy",   "color" : "transluscent",    "density" : "low",      "magnetism" : "none", "system" : "triclinic",    "effervescence" : "none"},
          {"name" : "bauxite",      "formula" : "n/a",     "streak" : "moldyRed",   "hardness" : "1-3",   "scratches" : "none",       "scratchedBy" : "fingernail", "luster" : "dull",     "color" : "pinkRed",         "density" : "low",      "magnetism" : "none", "system" : "none",         "effervescence" : "none"},
          {"name" : "kaolinite",    "formula" : "n/a",     "streak" : "white",      "hardness" : "1.5-2", "scratches" : "none",       "scratchedBy" : "fingernail", "luster" : "dull",     "color" : "white",           "density" : "low",      "magnetism" : "none", "system" : "triclinic",    "effervescence" : "none"},
          {"name" : "hematite",     "formula" : "Fe_2O_3", "streak" : "redBrown",   "hardness" : "6.5",   "scratches" : "nail",       "scratchedBy" : "nail",       "luster" : "metallic", "color" : "dark",            "density" : "high",     "magnetism" : "none", "system" : "hexagonal",    "effervescence" : "none"},
          {"name" : "malachite",    "formula" : "n/a",     "streak" : "lightGreen", "hardness" : "3.5-4", "scratches" : "fingernail", "scratchedBy" : "penny",      "luster" : "dull",     "color" : "green",           "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "azurite",      "formula" : "n/a",     "streak" : "lightBlue",  "hardness" : "3.5-4", "scratches" : "fingernail", "scratchedBy" : "penny",      "luster" : "dull",     "color" : "blue",            "density" : "moderate", "magnetism" : "none", "system" : "monoclinit",   "effervescence" : "yes"},
          {"name" : "bornite",      "formula" : "n/a",     "streak" : "black",      "hardness" : "3-3.5", "scratches" : "fingernail", "scratchedBy" : "penny",      "luster" : "metallic", "color" : "iridescent",      "density" : "high",     "magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "chalcopyrite", "formula" : "n/a",     "streak" : "green",      "hardness" : "3.5-4", "scratches" : "penny",      "scratchedBy" : "glass",      "luster" : "metallic", "color" : "brass",           "density" : "moderate", "magnetism" : "none", "system" : "tetragonal",   "effervescence" : "none"},
          {"name" : "pyrite",       "formula" : "FeS_2",   "streak" : "green",      "hardness" : "6-6.5", "scratches" : "glass",      "scratchedBy" : "nail",       "luster" : "metallic", "color" : "gold",            "density" : "moderate", "magnetism" : "none", "system" : "isometric",    "effervescence" : "none"},
          {"name" : "galena",       "formula" : "n/a",     "streak" : "steel",      "hardness" : "2.5-3", "scratches" : "fingernail", "scratchedBy" : "penny",      "luster" : "metallic", "color" : "steel",           "density" : "extreme",  "magnetism" : "none", "system" : "isometric",    "effervescence" : "none"}]
groups.append(group4)
sets.append("group4")
#####################################################################################################
group5 = [{"name" : "staurolite",   "formula" : "n/a",       "streak" : "white",     "hardness" : "7-7.5",   "scratches" : "nail",  "scratchedBy" : "none",       "luster" : "dull",         "color" : "rust",           "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "wollastonite", "formula" : "n/a",       "streak" : "white",     "hardness" : "4.5-5",   "scratches" : "penny", "scratchedBy" : "glass",      "luster" : "silky",        "color" : "white",          "density" : "moderate", "magnetism" : "none", "system" : "triclinic",    "effervescence" : "dissolves"},
          {"name" : "actinolite",   "formula" : "n/a",       "streak" : "colorless", "hardness" : "5.5-6",   "scratches" : "glass", "scratchedBy" : "nail",       "luster" : "silky",        "color" : "greenBlack",     "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "serpentinite", "formula" : "n/a",       "streak" : "white",     "hardness" : "2-5",     "scratches" : "penny", "scratchedBy" : "glass",      "luster" : "greasy",       "color" : "green",          "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "chlorite",     "formula" : "n/a",       "streak" : "white",     "hardness" : "2-2.5",   "scratches" : "none",  "scratchedBy" : "fingernail", "luster" : "pearly",       "color" : "darkGreen",      "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "talc",         "formula" : "n/a",       "streak" : "white",     "hardness" : "1",       "scratches" : "none",  "scratchedBy" : "everything", "luster" : "waxy",         "color" : "beige",          "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"},
          {"name" : "kyanite",      "formula" : "Al_2SiO_5", "streak" : "colorless", "hardness" : "4.5-7",   "scratches" : "penny", "scratchedBy" : "glass/nail", "luster" : "vitreous",     "color" : "cobalt",         "density" : "moderate", "magnetism" : "none", "system" : "triclinic",    "effervescence" : "none"},
          {"name" : "andalusite",   "formula" : "Al_2SiO_5", "streak" : "white",     "hardness" : "7-7.5",   "scratches" : "nail",  "scratchedBy" : "glass",      "luster" : "glassy",       "color" : "warmMulticolor", "density" : "moderate", "magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "sillimanite",  "formula" : "Al_2SiO_5", "streak" : "colorless", "hardness" : "6.5-7.5", "scratches" : "glass", "scratchedBy" : "none",       "luster" : "chatoyant",    "color" : "brownGray",      "density" : "moderate", "magnetism" : "none", "system" : "orthorhombic", "effervescence" : "none"},
          {"name" : "epidote",      "formula" : "n/a",       "streak" : "white",     "hardness" : "6-7",     "scratches" : "glass", "scratchedBy" : "nail",       "luster" : "glassy",       "color" : "brown/green",    "density" : "moderate", "magnetism" : "none", "system" : "monoclinic",   "effervescence" : "none"}] 
groups.append(group5)
sets.append("group5")
#####################################################################################################

    # extract only mineral name and formula from the larger dataset
def getFormulae(mineralSet):
    minList = []
    
    for mineral in mineralSet:
        minDict = {}
        minList.append({"name" : mineral["name"], "formula" : mineral["formula"]})
        
    return minList

for group in groups :
    data.append(getFormulae(group))
    
for datum in data:
    for mineral in datum:
        allMinerals.append(mineral)
        
minsDF = pd.DataFrame(allMinerals)

# define functions
def runTest(inds):
    """
    Conducts study session for the given active set.
    """
    
    minScore = 0
    
    for i in inds:
        response = input(f"Your mineral is {activeSet[i]['name']}. What is this mineral's formula?  ")
        print("")
        
        if response == activeSet[i]["formula"]:
            print("Correct! Good work")
            print("")
            print("----------------------------------------")
            
            minScore += 1
        else:
            print(f"Incorrect. This mineral's formula is {activeSet[i]['formula']}")
            print("")
            input("Copy the formula to proceed.  ")
            print("----------------------------------------")
            
    return print(int(minScore)/int(setSize))
    
def didYouDoGood(finalScore, ):
    """
    Tells the studyer how they did during their study session.
    """
    
    propCorrect = int(score)/int(setSize)
    
    print("")
    print(f"Thanks for your hard work! You identified {score}/{setSize} mineral formulae correctly!")
    if propCorrect <= 0.6:
        print("Unfortunately, you did fail this study session!")
        print("")
        print("But don't be discouraged! Remember that practice makes perfect.")
    elif propCorrect <= 0.7:    
        print("You recieve a D for this study session.")
        print("D's get degrees but I think that you can do better. Want to try again?")
    elif propCorrect <= 0.8:
        print("You recieve a C for this study session.")
        print("")
        print("Moving up! Great work.")
    elif propCorrect <= 0.9:
        print("You've earned a B!")
        print("")
        print("I'm feeling good! Think we can keep up the streak?")
    elif propCorrect < 1:
        print("You got an A! You're in great shape for your quiz.")
    else:
        print("100%? Amazing! You're a formula master.")
        
    return none

# display data frame for reference during studying session
minsDF
# Out:
#             name                                            formula
# 0        olivine                                          Mg_2SiO_4
# 1         augite                   (Na,Ca)(Fe,Al,Ti,Mg)(Si,Al)_2O_6
# 2       diopside                                        CaMgSi_2O_6
# 3     hornblende  (Ca,Na)_(2-3)(Mg,Fe,Al)_5Si_6(Si,Al)_2O_(22)(O...
# 4        biotite                         K(Mg,Fe)_3AlSi_3O_10(OH)_2
# 5       ilmenite                                            FeTiO_3
# 6      magnetite                                            Fe_3O_4
# 7       chromite                                          FeCr_2O_4
# 8         quartz                                              SiO_2
# 9      anorthite                                      CaAl_2Si_2O_8
# 10   plagioclase                                (Ca,Na)(Al,Si)_3O_8
# 11        albite                                        NaAlSi_3O_8
# 12    orthoclase                                         KAlSi_3O_8
# ...

# %%
# begin playing the game

minScore = 0

print("Current mineral sets available to study:")
print("")
print("all")
for group in sets:
    print(str(group))
print("")
print("Please enter the number of the set you would like to study.")
res1 = input("Your response: ")

if res1 == "all":
    activeSet = allMinerals
elif res1 == "group1":
    activeSet = group1
elif res1 == "group2":
    activeSet = group2
elif res1 == "group3":
    activeSet = group3
elif res1 == "group4":
    activeSet = group4
elif res1 == "group5":
    activeSet = group5
        
print("")
print("Are you ready to begin?")
res2 = input("Y/N: ")
print("")

if res2 == "Y":
    print("Alright! Let's rock, mineral, soil, and roll!")
else:
    print("Too bad. You have to study.")
# Out:
# Current mineral sets available to study:
#
# all
# group1
# group2
# group3
# group4
# group5
#
# Please enter the number of the set you would like to study.
# Your response: all
#
# Are you ready to begin?
# Y/N: Y
#
# Alright! Let's rock, mineral, soil, and roll!

# %%
if activeSet == allMinerals:
    print("How many minerals would you like to study?")
    setSize = input(f"Please enter a number between 1 and {len(allMinerals)}: ")
    
    inds = list(range(0, int(setSize)))
    r.shuffle(inds)
    
    score = runTest(inds)
    #performance = didYouDoGood(score, setSize)
    #performance        
else:
    print(f"Your set contains {len(activeSet)} minerals.")
    print("")
    setSize = len(activeSet)
    inds = list(range(0, setSize))
    r.shuffle(inds)
    
    
    score = runTest(inds)
    #performance = didYouDoGood(score, setSize)
    #performance
# Out:
# How many minerals would you like to study?
# Please enter a number between 1 and 51: 51
# Your mineral is actinolite. What is this mineral's formula?
#
# Incorrect. This mineral's formula is n/a
#
# Copy the formula to proceed.
# ----------------------------------------
# Your mineral is plagioclase. What is this mineral's formula?
#
# Incorrect. This mineral's formula is (Ca,Na)(Al,Si)_3O_8
#
# Copy the formula to proceed.
# ----------------------------------------
# Your mineral is sphene. What is this mineral's formula?
#
# Incorrect. This mineral's formula is n/a
#
# Copy the formula to proceed.
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       5     inds = list(range(0, int(setSize)))
#       6     r.shuffle(inds)
# ----> 8     score = runTest(inds)
# ...
